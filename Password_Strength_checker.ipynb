# %%
def check_password_strength(password):
    length = len(password)
    has_uppercase = any(char.isupper() for char in password)
    has_lowercase = any(char.islower() for char in password)
    has_digit = any(char.isdigit() for char in password)
    has_special_char = any(char in "!@#$%^&*()-+" for char in password)

    if length >= 8 and has_uppercase and has_lowercase and has_digit and has_special_char:
        return "Strong password! 🚀"
    else:
        return "Weak password. Consider adding uppercase letters, digits, and special characters."
user_password = input("Enter your password: ")
strength_feedback = check_password_strength(user_password)
print(strength_feedback)
# Out:
# Enter your password: Password
# Weak password. Consider adding uppercase letters, digits, and special characters.

# %%
# Out:
# Enter your password: P@$$w0rd
# Strong password! 🚀
